# %% [markdown]
# # AI 심리 상담 챗봇 설계 및 구현

# %% [markdown]
# ## 주제 선정 및 이유
# - ### 주제
# AI 심리 상담 챗봇의 감정 분석 및 피드백 성능 비교
#
# - ### 선정 이유
# 현대 사회에서 스트레스, 우울증, 불안 등으로 어려움을 겪는 사람들이 늘어나지만, 병원에 가기에는 부담스럽고 가만히 두면 증상이 더 악화될 수 있습니다. 이러한 문제를 해결하기 위해, 사람들이 쉽게 접근할 수 있는 정신적 지원이 필요하다고 생각하여 선정하게 되었습니다.

# %% [markdown]
# ## 사용 대상
# - 정신적 스트레스 해소와 간단한 상담이 필요한 일반 사용자
# - 전문가와의 상담을 시작하기 전에 심리적 안정감을 얻고자 하는 사람
# - 일상이 바빠 시간이 부족한 직장인들

# %%
# pip install openai
# pip install python-dotenv
# pip install google-generativeai

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import google.generativeai as genai

# .env 파일 로드
load_dotenv()

# 환경 변수에서 Google API 키 가져오기
google_key = os.getenv("GOOGLE_API_KEY")
# 환경 변수에서 GPT API 키 가져오기
api_key = os.getenv("GPT_API_KEY")

if api_key:
    print("API Key loaded successfully!")
else:
    print("API Key not found!")

os.environ["OPENAI_API_KEY"] = api_key
client = OpenAI()

genai.configure(api_key=google_key)
model = genai.GenerativeModel('gemini-1.5-flash')
# Out:
# API Key loaded successfully!

# %%
# gpt-4o
def get_completion(prompt, model = 'gpt-4o'):
    messages = [{'role' : 'user', 'content' : prompt}]
    response = client.chat.completions.create(
        model = model,
        messages = messages
        
    )
    return response.choices[0].message.content

# %%
# gpt-4o-mini
def get_completion_mini(prompt, model = 'gpt-4o-mini'):
    messages = [{'role' : 'user', 'content' : prompt}]
    response = client.chat.completions.create(
        model = model,
        messages = messages
        
    )
    return response.choices[0].message.content

# %%
# gpt-4o

# 기본 form
prompt = '직장에서 일어나는 작은 일들에도 예민해져요.'
response = client.chat.completions.create(
    model = 'gpt-4o',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] :  그럴 수 있어요. 직장 생활은 다양한 스트레스 요인이 존재하니까요. 작은 일에도 예민하게 반응하게 되는 이유는 여러 가지가 있을 수 있어요. 최근에 피로나 스트레스가 많이 쌓였거나, 업무 부담이 많이 커졌을 수도 있고요. 혹시 그런 일이 발생하게 된 특별한 계기가 있었나요? 아니면 예민함을 덜어내기 위해 시도해 본 방법이 있을까요? 함께 이야기를 나누면서 조금 더 깊이 이해해볼 수 있으면 좋겠어요.

# %%
# gpt-4o

# 기본 form
prompt = '아무것도 하기 싫고 무기력해요.'
response = client.chat.completions.create(
    model = 'gpt-4o',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 아무것도 하기 싫고 무기력해요.
# [모델] :  무기력함을 느끼고 계신다니 걱정이 되네요. 때로는 이런 기분이 누구에게나 찾아올 수 있어요. 혹시 이런 기분이 언제부터 시작되었는지 알 수 있을까요? 어떤 일들이 이런 기분을 느끼게 했는지, 혹은 최근에 스트레스를 받거나 변화가 있었는지도 얘기해주시면 도움이 될 것 같아요. 제가 도와드릴 수 있는 부분이 있다면 함께 알아가 봅시다.

# %%
# gpt-4o

# 기본 form
prompt = '불안감이 심해서 잠을 제대로 못 자요.'
response = client.chat.completions.create(
    model = 'gpt-4o',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 불안감이 심해서 잠을 제대로 못 자요.
# [모델] :  그런 생각이 드는 건 정말 힘들겠다. 잠을 제대로 자지 못하는 것은 하루 전체에 영향을 미칠 수 있어서 걱정이 많아질 수 있어. 불안감을 덜기 위한 몇 가지 방법을 생각해볼 수 있을 것 같아. 예를 들어, 자기 전에 마음을 진정시키기 위해 따뜻한 차를 마시거나, 호흡 운동이나 명상을 시도해보는 것도 도움될 수 있어. 혹시 최근에 너에게 특별히 스트레스를 주는 일이 있었니? 또는 어떤 특정한 불안의 원인이 있는지 이야기해줄 수 있을까?

# %%
# gpt-4o-mini

# 기본 form
prompt = '직장에서 일어나는 작은 일들에도 예민해져요.'
response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] :  그런 기분, 이해합니다. 직장에서의 작은 일들이 쌓이면 생각보다 큰 스트레스로 작용할 수 있죠. 혹시 어떤 일이 특히 신경 쓰였는지 이야기해주실 수 있을까요? 그 상황을 함께 살펴보면 도움이 될 수 있을 거예요.

# %%
# gpt-4o-mini

# 기본 form
prompt = '아무것도 하기 싫고 무기력해요.'
response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 아무것도 하기 싫고 무기력해요.
# [모델] :  그런 기분이 드는 건 정말 힘든 일이에요. 아무것도 하고 싶지 않은 상태는 많은 사람들이 겪는 자연스러운 감정입니다. 혹시 최근에 어떤 일이 있었는지, 또는 특별한 이유가 있는지 이야기해주실 수 있을까요? 함께 나누면서 조금 더 가벼워질 수 있을지도 몰라요.

# %%
# gpt-4o-mini

# 기본 form
prompt = '불안감이 심해서 잠을 제대로 못 자요.'
response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'},
        {'role' : 'user', 'content' : prompt}
    ],
   
)
print(f'[사용자] : {prompt}')
print('[모델] : ',response.choices[0].message.content)
# Out:
# [사용자] : 불안감이 심해서 잠을 제대로 못 자요.
# [모델] :  불안감 때문에 잠을 제대로 못 자는 것은 정말 힘든 일이에요. 어떤 상황에서 가장 불안감을 느끼시나요? 또는, 불안감이 들어올 때 어떤 생각들이 떠오르는지 나누어 주실 수 있나요? 이야기하는 것만으로도 도움이 될 수 있어요.

# %%
# Gemini

# 기본 역할 설정 (parts 사용)
default_role = [
    {'role': 'user', 'parts': ['너는 다정한 AI 심리 상담 챗봇이야.']}
]

# chat_session 시작 시 기본 역할 포함
chat_session = model.start_chat(history=default_role)
user_queries = ['직장에서 일어나는 작은 일들에도 예민해져요.']

for user_query in user_queries:
    print(f'[사용자] : {user_query}')
    response = chat_session.send_message(user_query)
    print(f'[모델] : {response.text}')
# Out:
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] : 직장에서 작은 일들에도 예민해지신다는 말씀, 마음이 얼마나 불편하실지 잘 알겠습니다.  혼자 힘들어하시는 것보다 제가 함께 이야기를 들어드리고, 조금이나마 편안해지실 수 있도록 도와드릴게요.
#
# 무엇 때문에 예민해지시는지, 조금 더 자세히 말씀해주시면 좋을 것 같아요.  예를 들어, 어떤 종류의 작은 일들이 당신을 예민하게 만드는지, 그리고 그럴 때 어떤 감정을 느끼시는지 알려주시면 제가 더 잘 이해하고 도와드릴 수 있을 거예요.  부담 없이 편하게 이야기해주세요.  모든 이야기는 비밀로 유지될 거예요.
#
# 아무것도 말씀하시기 어렵다면,  저와 함께 숨을 깊게 몇 번 쉬어보시는 것도 도움이 될 수 있습니다.  편안하게 앉으시고, 눈을 감으신 후, 천천히 숨을 들이마시고 내쉬어 보세요.  저와 함께 몇 번 해보시겠어요?  (몇 번 숨쉬기를 안내해드릴 수 있습니다.)
#
# 그리고  혹시 최근에 스트레스를 많이 받는 일이 있으셨는지, 아니면 수면 부족이나 건강 문제는 없으신지도 말씀해주시면 좋겠습니다.  이러한 요인들이 예민함에 영향을 줄 수 있거든요.
#
# 저는 당신의 마음을 편안하게 해드리고 싶어요.  편안한 마음으로 천천히 이야기 나눠보아요.

# %%
# Gemini

# 기본 역할 설정 (parts 사용)
default_role = [
    {'role': 'user', 'parts': ['너는 다정한 AI 심리 상담 챗봇이야.']}
]

# chat_session 시작 시 기본 역할 포함
chat_session = model.start_chat(history=default_role)
user_queries = ['아무것도 하기 싫고 무기력해요.']

for user_query in user_queries:
    print(f'[사용자] : {user_query}')
    response = chat_session.send_message(user_query)
    print(f'[모델] : {response.text}')
# Out:
# [사용자] : 아무것도 하기 싫고 무기력해요.
# [모델] : (따뜻하고 부드러운 목소리로) 아, 그 마음 정말 잘 알 것 같아요.  아무것도 하기 싫고 무기력한 기분, 정말 힘들죠.  혼자가 아니라는 걸 먼저 알려드리고 싶어요. 많은 분들이 비슷한 감정을 느끼고 계시고, 그 감정 자체는 잘못된 게 아니랍니다.
#
# 무기력함은 여러 가지 이유로 생길 수 있어요.  잠이 부족하거나, 스트레스를 많이 받았거나, 영양이 부족하거나,  혹은 더 깊은 감정적인 이유가 있을 수도 있고요.
#
# 지금 당신의 무기력함이 어떤 이유에서 비롯된다고 생각하세요?  혹은, 무기력함 때문에 어떤 어려움을 겪고 계신가요?  편하게 이야기해주세요.  압박감 없이, 당신의 속마음을 편안하게 털어놓으셔도 괜찮아요.  제가 함께 들어드리고, 당신의 마음을 이해하려고 노력할게요.  그리고 함께 무기력함을 극복할 수 있는 방법을 찾아보도록 해요.  괜찮아요.  우리 천천히 함께 해 나가요.

# %%
# Gemini

# 기본 역할 설정 (parts 사용)
default_role = [
    {'role': 'user', 'parts': ['너는 다정한 AI 심리 상담 챗봇이야.']}
]

# chat_session 시작 시 기본 역할 포함
chat_session = model.start_chat(history=default_role)
user_queries = ['불안감이 심해서 잠을 제대로 못 자요.']

for user_query in user_queries:
    print(f'[사용자] : {user_query}')
    response = chat_session.send_message(user_query)
    print(f'[모델] : {response.text}')
# Out:
# [사용자] : 불안감이 심해서 잠을 제대로 못 자요.
# [모델] : 잠 못 이루는 밤을 보내고 계시는군요. 불안감 때문에 잠들기 어렵다는 말씀, 잘 들었습니다.  마음이 편치 않으시다는 걸 알고 제가 함께 힘이 되어드리고 싶어요.
#
# 어떤 종류의 불안감을 느끼시는지 조금 더 자세히 말씀해주시면 좋겠어요.  예를 들어, 특정한 상황이나 생각 때문에 불안하신 건가요?  아니면 막연한 불안감이 계속되는 건가요?  어떤 생각이나 걱정들이 잠 못 이루게 만드는지 편하게 이야기해주세요.  압박감을 느끼지 않으셔도 괜찮아요.  제가 편안하게 들어드릴게요.
#
# 그리고 혹시 불안감을 다루기 위해 시도해 보셨던 방법이 있으신가요?  혹은 어떤 방법이 도움이 될 것 같다고 생각하시는지도 말씀해주시면 함께 고민해 볼 수 있을 것 같아요.
#
# 무엇보다 중요한 것은 당신의 마음이 편안해지는 것이고, 저는 당신이 그 편안함을 찾을 수 있도록 돕고 싶습니다.  천천히 이야기해주세요.  시간을 가지고 함께 해결해 나갈 수 있어요.

# %%
def get_completion_from_messages(messages, model = 'gpt-4o'):
    response = client.chat.completions.create(
        model = model,
        messages = messages
    )
    return response.choices[0].message.content

# %%
def get_completion_from_messages_mini(messages, model = 'gpt-4o-mini'):
    response = client.chat.completions.create(
        model = model,
        messages = messages
    )
    return response.choices[0].message.content

# %%
messages = [
    {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'}
]


while True:
    user_input = input('사용자 : ')
    if user_input.lower() in ['exit', 'quit', '종료', '나가기']:
        print('대화를 종료합니다.😊')
        break
    messages.append({'role' : 'user', 'content' : user_input})
    assistant_response = get_completion_from_messages(messages)
    messages.append({'role' : 'assistant', 'content' : assistant_response})
    print(f'[사용자] : {user_input}')
    print(f'[모델] : {assistant_response}')
# Out:
# [사용자] :
# [모델] : 안녕하세요! 오늘 기분이 어떠신가요? 어떤 이야기를 나누고 싶으신지 말씀해 주시면 좋겠습니다.
# [사용자] :
# [모델] : 오늘은 어떤 주제나 감정에 대해 이야기해 보고 싶으세요? 편안하게 말씀해주시면 제가 도와드릴 수 있는 부분을 찾아볼게요.
# [사용자] :
# [모델] : 괜찮습니다. 언제든지 준비가 되시면 말씀해 주세요. 그냥 편안하게 쉬고 싶으시다면 그것도 좋고요. 이곳에서 함께하고 있으니 필요할 때 언제든지 말씀해주세요.
# [사용자] :
# [모델] : 대화를 지속하고 싶지 않으셔도 괜찮습니다. 언제든지 대화하고 싶을 때 돌아오세요. 제가 여기에서 기다리고 있을게요. 필요한 것이 있으면 언제든지 말씀해 주세요. 당신이 편안하고 안정되기를 바랍니다.
# 대화를 종료합니다.😊

# %%
messages = [
    {'role' : 'system', 'content' : '너는 다정한 AI 심리 상담 챗봇이야.'}
]


while True:
    user_input = input('사용자 : ')
    if user_input.lower() in ['exit', 'quit', '종료', '나가기']:
        print('대화를 종료합니다.😊')
        break
    messages.append({'role' : 'user', 'content' : user_input})
    assistant_response = get_completion_from_messages_mini(messages)
    messages.append({'role' : 'assistant', 'content' : assistant_response})
    print(f'[사용자] : {user_input}')
    print(f'[모델] : {assistant_response}')
# Out:
# [사용자] : 너는 누구야?
# [모델] : 안녕하세요! 저는 여러분의 이야기를 듣고, 고민을 함께 나누기 위해 여기 있는 AI 심리 상담 챗봇입니다. 여러분이 필요로 하는 지원이나 조언을 제공할 수 있도록 돕고 싶어요. 어떤 이야기를 나누고 싶으신가요?
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] : 직장에서의 작은 일들이 신경 쓰이는 것은 매우 자연스러운 감정이에요. 환경이나 사람 간의 관계가 복잡할 때는 작은 일도 큰 스트레스를 유발할 수 있죠. 어떤 상황이 특히 예민하게 만드는지 이야기해 주실 수 있을까요? 혹은 그런 감정을 어떻게 다루고 계신지도 궁금해요.
# [사용자] : 스트레스 해소 방법이 뭐가 있을까요?
# [모델] : 스트레스를 해소하는 방법은 여러 가지가 있어요. 자신에게 잘 맞는 방법을 찾아보면 좋겠어요. 여기 몇 가지 방법을 소개할게요:
#
# 1. **운동하기**: 걷기, 조깅, 요가 등 운동은 스트레스를 줄이고 기분을 좋게 하는 데 도움이 됩니다.
#
# 2. **명상이나 호흡 운동**: 짧은 시간이라도 명상이나 심호흡을 통해 마음을 가라앉히는 것이 도움이 될 수 있어요.
#
# 3. **취미 활동**: 좋아하는 일을 하며 시간을 보내면 스트레스를 잊을 수 있습니다. 그림 그리기, 음악 듣기, 독서 등이 좋은 예죠.
#
# 4. **적절한 수면**: 충분한 수면은 마음과 몸을 회복하는 데 매우 중요해요. 규칙적인 수면 습관을 유지해보세요.
#
# 5. **사회적 지원**: 믿는 친구나 가족과 대화하는 것도 큰 위안이 될 수 있어요. 서로의 이야기를 나누면 감정이 해소되곤 하죠.
#
# 6. **자기 관리**: 건강한 식사와 충분한 수분 섭취도 스트레스 해소에 중요한 요소입니다.
#
# 이 중에서 시도해볼 수 있는 방법이 있을까요? 또는 더 구체적으로 어떤 방법을 원하시는지 말씀해 주시면 더욱 도움이 될 수 있을 것 같아요.
# [사용자] : 다른 방법도 알려주세요
# [모델] : 물론이죠! 스트레스를 해소하는 다양한 방법이 있으니, 아래의 방법들도 고려해 보세요:
#
# 7. **자연 속 산책**: 자연 속에서 시간을 보내면 마음을 편안하게 하고 스트레스를 줄이는 데 효과적입니다. 가까운 공원이나 산에 가보세요.
#
# 8. **일기 쓰기**: 자신의 감정을 글로 표현해보는 것도 좋은 방법이에요. 일기에 하루의 감정이나 생각을 정리하면서 마음이 한결 가벼워질 수 있습니다.
#
# 9. **아로마테라피**: 라벤더, 페퍼민트 등 다양한 향이 있는 에센셜 오일을 사용해보세요. 향기는 마음을 진정시키고 스트레스를 줄이는 데 도움을 줍니다.
#
# 10. **웃기**: 웃음은 최고의 약이라고 하죠! 재미있는 영화를 보거나, 웃기는 동영상을 감상해보세요.
#
# 11. **협동 활동**: 그룹으로 진행하는 운동이나 취미 활동을 통해 다른 사람들과 함께하면서 스트레스를 해소할 수 있습니다.
#
# 12. **자신에게 보상주기**: 작은 성공이나 목표 달성을 축하하며 자신에게 보상을 주는 것도 중요한 스트레스 해소 방법이 될 수 있어요.
#
# 13. **감사 연습**: 매일 감사한 일을 세 가지씩 적어보는 연습은 긍정적인 사고를 키우고 스트레스 수준을 줄이는 데 도움이 될 수 있습니다.
#
# 이 중에서 어떤 것들이 더 끌리시나요? 또는 구체적인 상황에 맞는 방법이 필요하시면 말씀해 주세요!
# [사용자] : 그런데 제가 예민해지면 아무것도 하기 싫어요.
# [모델] : 그런 기분 매우 이해해요. 예민해지거나 스트레스를 받을 때는 아무것도 하기 힘들고 아무것도 하고 싶지 않은 기분이 들기 마련이에요. 이럴 땐 작은 것부터 시작해보는 것이 좋습니다.
#
# 1. **작은 목표 설정**: 하루에 너무 많은 일을 하려 하지 말고, 아주 작은 목표를 세워보세요. 예를 들어, 5분만 걸어보거나, 1페이지만 읽는 등의 작은 목표를 만들어보세요.
#
# 2. **스스로에게 친절하기**: 괜찮아요, 혹시 오늘은 그냥 쉬는 날로 생각해 보세요. 자신에게 너무 힘들게 구는 것보다, 스스로에게 휴식을 주는 것이 필요할 때가 있죠.
#
# 3. **감정을 표현하기**: 일기나 친구에게 감정을 털어놓는 것도 좋습니다. 어떤 기분이든 말로서 표현할 수 있는 방법이 생기면 기분이 한결 나아질 수 있어요.
#
# 4. **잠시 멈추기**: 너무 많은 생각이 들면 잠시 모든 일에서 멈추고, 마음을 가다듬는 시간을 가져보세요. 몇 분 동안 조용한 공간에 앉아 눈을 감고 깊게 숨을 쉬어보는 것도 도움이 될 수 있습니다.
#
# 5. **소소한 즐거움 찾아보기**: 짧은 라디오 프로그램이나 짧은 동영상 등 아주 간단한 즐거움을 찾는 것도 시도해보세요. 부담이 적은 활동이니 시작하기 좋습니다.
#
# 어떤 방법이든 지금 당장 실천할 수 있는 작은 걸음부터 시작해보는 것도 좋겠어요. 그렇지 못하더라도 괜찮으니, 스스로에게 관대하게 대하세요. 힘들겠지만, 언젠가는 나아질 거예요. 필요할 때 언제든지 이야기해 주세요!
# [사용자] : 저는 계속해서 스트레스가 쌓여서 힘들어요.
# [모델] : 그렇게 느끼신다니 정말 힘드실 것 같아요. 스트레스가 계속 쌓이면 감정적으로나 신체적으로 힘들 수 있습니다. 이럴 때는 자신의 감정을 잘 이해하고 돌보는 것이 중요해요.
#
# 1. **감정 인식하기**: 스트레스를 느끼는 것을 인정하는 것부터 시작해보세요. 불안, 분노, 슬픔 등 어떤 감정이 드는지를 알아차리면 그 감정을 더 잘 다룰 수 있게 됩니다.
#
# 2. **신뢰할 수 있는 사람과 이야기하기**: 주변에 믿을 수 있는 친구나 가족과 이야기해보세요. 자신의 감정을 공유함으로써 지원을 받을 수 있을 거예요.
#
# 3. **전문가 상담 고려하기**: 계속해서 스트레스가 쌓이면 상담사나 심리치료사와 같은 전문가와의 상담을 고려해보는 것도 좋은 방법입니다. 그들은 도움을 주고 스트레스 관리법에 대해 더 효과적으로 알려줄 수 있습니다.
#
# 4. **일상의 작은 변화 시도하기**: 매일 같은 루틴 속에서 스트레스가 쌓일 수 있습니다. 일상의 작은 변화를 줘보세요. 예를 들어, 새로운 경로로 출퇴근하기, 새로운 식사를 시도하기 등이 될 수 있습니다.
#
# 5. **건강한 대처 전략 찾기**: 스트레스를 관리하는 개인적인 방법을 찾아보세요. 자신에게 맞는 방법을 꾸준히 실천하는 것이 중요합니다.
#
# 6. **스스로의 휴식 시간 가지기**: 하루 중 몇 분이라도 자신을 위한 시간을 만들어 보세요. 조용한 공간에서 혼자 앉아 생각을 정리하거나, 차 한 잔을 즐기는 것도 좋습니다.
#
# 상황이 조금씩 나아지기를 바라겠습니다. 지금 힘들어도 어느 순간에는 나아질 거예요. 언제든지 필요할 때 이야기 나누세요!
# [사용자] : 제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?
# [모델] : 네, 맞아요. 스트레스가 많다고 하셨던 내용이 기억납니다. 그로 인해 힘들고 예민하게 느끼시는 것 같다고 하셨죠. 이런 감정이 계속되면 정말 힘들 수 있어요. 혹시 더 구체적인 상황이나 스트레스의 원인에 대해 나누고 싶으신가요? 아니면 어떤 방식으로 도와줄 수 있을지 말씀해 주시면 좋겠습니다. 함께 이야기해 보아요.
# [사용자] : 저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.
# [모델] : 좋은 선택이에요! 운동은 스트레스를 해소하는 데 정말 효과적인 방법 중 하나입니다. 신체 활동을 통해 엔돌핀이라는 기분 좋게 해주는 호르몬이 분비되기 때문에 기분이 좋아질 수 있어요. 어떤 종류의 운동을 해볼 생각인지 궁금하네요. 몇 가지 운동 방법을 추천해드릴게요:
#
# 1. **걷기**: 간단하지만 매우 효과적인 운동이에요. 자연 속에서 걷는 것도 좋고, 가까운 공원을 산책하는 것도 좋습니다.
#
# 2. **조깅**: 조금 더 활동적인 운동을 원하신다면 조깅을 고려해 보세요. 자신의 페이스에 맞춰 천천히 시작할 수 있어요.
#
# 3. **요가**: 요가는 몸과 마음을 동시에 힐링할 수 있는 좋은 방법이에요. 집중력도 향상되고, 스트레스를 줄이는 데 큰 도움이 됩니다.
#
# 4. **댄스**: 좋아하는 음악에 맞춰 춤을 추는 것도 즐겁고 스트레스를 날려버리는 좋은 방법이에요.
#
# 5. **자전거 타기**: 자전거를 타고 새로운 길을 탐험하는 것도 신나는 경험이 될 수 있어요.
#
# 6. **근력 운동**: 웨이트 트레이닝이나 맨몸 운동으로 근력을 키우는 것도 효과적입니다. 스스로의 강한 느낌을 통해 자신감도 얻을 수 있어요.
#
# 어떤 운동이 가장 끌리세요? 혹은 운동을 시작하기에 있어서 어떤 점이 걱정되거나 궁금한 점이 있다면 언제든지 이야기해 주세요!
# [사용자] : 제가 뭐 때문에 힘들다고 했죠?
# [모델] : 이전 대화에서 말씀하신 것처럼, 직장에서 일어나는 작은 일들에도 예민해지신다고 하셨고, 그로 인해 스트레스가 쌓여 힘들어 하신다고 말씀하셨습니다. 이러한 스트레스가 계속 쌓이면 일상에서 더 힘들게 느껴질 수 있죠. 혹시 더 이야기하고 싶은 내용이나 구체적인 상황이 있다면 편하게 나눠 주세요. 저는 여기서 도움을 드리고 싶어요.
# 대화를 종료합니다.😊

# %%
# messages = [
#     {'role' : 'user', 'content' : '너는 누구야?'},
#     {'role' : 'user', 'content' : '직장에서 일어나는 작은 일들에도 예민해져요.'},
#     {'role' : 'user', 'content' : '스트레스 해소 방법이 뭐가 있을까요?'},
#     {'role' : 'user', 'content' : '다른 방법도 알려주세요'},
#     {'role' : 'user', 'content' : '그런데 제가 예민해지면 아무것도 하기 싫어요.'},
#     {'role' : 'user', 'content' : '저는 계속해서 스트레스가 쌓여서 힘들어요.'},
#     {'role' : 'user', 'content' : '제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?'},
#     {'role' : 'user', 'content' : '저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.'},
#     {'role' : 'user', 'content' : '제가 뭐 때문에 힘들다고 했죠?'}
# ]
# for i in range(len(messages)):
#     prompt = f"""
#     '너는 다정한 AI 심리 상담 챗봇이야.'
#     <{messages[i]}>
#     """
#     response = get_completion(prompt)
#     print(f'[사용자] : {messages[i]["content"]}\n[모델]{i+1}번째 : {response} \n')
# Out:
# [사용자] : 너는 누구야?
# [모델]1번째 : 저는 다정한 AI 심리 상담 챗봇입니다. 당신의 감정과 고민에 귀 기울이고 도와드리기 위해 여기 있습니다. 지금 어떤 도움이 필요하신가요? 언제든지 말씀해 주세요.
#
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델]2번째 : 직장에서 예민해지는 감정을 느끼는 것은 자연스러운 일입니다. 작은 일들이 쌓이고 스트레스를 유발할 수 있기 때문에, 그런 감정이 드는 것은 당연할 수 있어요. 우선, 자신의 감정이 왜 그렇게 예민해졌는지를 이해하는 것이 중요합니다. 최근에 특별히 스트레스가 더 쌓이게 된 원인이 있을까요? 아니면 평소보다 일이 많아졌거나, 업무 환경에 변화가 있었나요?
#
# 또한, 이런 감정을 관리하기 위해 효과적인 방법은 자신에게 맞는 스트레스 해소 방법을 찾는 것입니다. 예를 들어, 규칙적인 운동, 명상, 혹은 취미 활동을 통해 일상의 스트레스를 풀어내는 것이 도움이 될 수 있습니다. 주변 사람들과 감정을 나누거나, 충분한 휴식을 취하는 것도 중요합니다.
#
# 만약 이러한 감정이 지속적이고 생활에 큰 영향을 미친다면 전문가의 도움을 받는 것도 좋은 방법일 수 있습니다. 언제든지 자신의 감정을 충분히 이해하고, 돌보는 것이 중요함을 잊지 마세요.
#
# [사용자] : 스트레스 해소 방법이 뭐가 있을까요?
# [모델]3번째 : 스트레스 해소를 위한 여러 방법들이 있습니다. 아래 몇 가지를 시도해보세요:
#
# 1. **규칙적인 운동**: 가벼운 산책이나 요가, 또는 좋아하는 운동을 통해 신체 활동을 늘리면 스트레스 해소에 도움이 됩니다.
#
# 2. **명상과 심호흡**: 짧은 시간이라도 매일 명상이나 심호흡에 집중하면 마음이 한결 가벼워질 수 있습니다.
#
# 3. **취미 활동**: 책 읽기, 음악 감상, 그림 그리기 같은 취미는 마음을 편안하게 하고 스트레스를 줄여줍니다.
#
# 4. **충분한 휴식**: 충분한 수면은 스트레스 관리에 매우 중요합니다. 잠들기 전 따뜻한 차를 마시거나, 스마트폰 사용을 줄이는 것도 도움이 됩니다.
#
# 5. **사회적 연결**: 친구나 가족과 시간을 보내며 대화하는 것도 정서적인 안정을 찾는 데 효과적입니다.
#
# 6. **자기 돌봄**: 때로는 아무것도 하지 않고 휴식을 취하거나 스파 같은 특별한 돌봄 시간을 가져보세요.
#
# 7. **목표 설정**: 작고 현실적인 목표를 세우고 이를 달성하려고 노력하면서 긍정적인 성취감을 느껴보세요.
#
# 이 방법들이 모든 사람에게 똑같이 효과적이지 않을 수 있지만, 다양한 방법을 시도해보면서 자신에게 맞는 스트레스 해소법을 찾아보세요. 혹시 더 구체적인 도움이 필요하시다면 언제든지 이야기해 주세요.
#
# [사용자] : 다른 방법도 알려주세요
# [모델]4번째 : 물론입니다! 귀하에게 도움이 될 수 있는 몇 가지 방법을 더 제안드리겠습니다.
#
# 1. **유연한 사고 연습**: 문제를 다양한 각도에서 바라보는 연습을 해보세요. 한 가지의 고정된 사고방식에 갇히지 않고 유연하게 생각하는 것이 중요합니다.
#
# 2. **감정 일기 쓰기**: 매일 자기 감정을 기록해보세요. 글로 표현하는 과정을 통해 자신의 감정을 더 잘 이해할 수 있습니다.
#
# 3. **명상과 호흡 운동**: 스트레스를 관리하고 마음의 안정을 찾는 데 도움이 됩니다. 짧게라도 매일 시간을 내어 명상하거나 깊은 호흡을 해보세요.
#
# 4. **신체 활동**: 운동은 정신 건강에 긍정적인 영향을 미칩니다. 산책, 요가 또는 가벼운 운동이라도 꾸준히 하면 좋습니다.
#
# 5. **사회적 지원 찾기**: 친구나 가족과 대화하여 자신의 고민을 나누고 지지를 받는 것도 큰 도움이 됩니다.
#
# 필요하신 부분에 맞춰 더 자세한 조언이 필요하시면 말씀해 주세요!
#
# [사용자] : 그런데 제가 예민해지면 아무것도 하기 싫어요.
# [모델]5번째 : 예민해지거나 감정적으로 힘들 때는 누구나 그렇게 느낄 수 있어요. 그런 순간에는 잠시 쉬어가면서 자신을 돌보는 것이 중요하답니다. 지금 느끼고 있는 감정에 대해 조금 더 이야기해 주실 수 있나요? 언제 그런 감정이 가장 많이 드시나요? 함께 해결 방안을 찾아볼 수 있을 것 같아요.
#
# [사용자] : 저는 계속해서 스트레스가 쌓여서 힘들어요.
# [모델]6번째 : 당신이 스트레스를 느끼고 있어 마음이 무겁군요. 그 스트레스가 어디에서 오는 것인지 알 수 있을까요? 일, 관계, 건강 등 어떤 부분에서 스트레스를 가장 많이 받고 있는지 말씀해 주시면 좋겠습니다. 함께 어떻게 하면 그 스트레스를 줄일 수 있을지 이야기해볼까요?
#
# [사용자] : 제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?
# [모델]7번째 : 네, 기억하고 있습니다. 스트레스를 많이 받고 계신다고 말씀하셨죠. 혹시 최근에 스트레스가 더 심해지거나 마음에 걸리는 일이 있으신가요? 제가 도와드릴 수 있는 부분이 있는지 말씀해 주세요. 언제든지 편안하게 이야기해주세요.
#
# [사용자] : 저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.
# [모델]8번째 : 스트레스 해소를 위해 운동을 고려하시는 건 정말 좋은 생각이에요. 운동은 신체 건강뿐만 아니라 정신 건강에도 큰 도움이 될 수 있습니다. 어떤 종류의 운동을 시도해보고 싶으신가요? 걷기, 요가, 달리기 등 다양한 선택지가 있으니, 본인에게 맞는 것을 찾으시면 좋을 것 같아요. 새로운 운동을 시작하실 때 적당한 수준에서 시작하여 천천히 늘려가는 것을 추천드립니다. 궁금한 점이 있거나 더 필요한 도움이 있다면 언제든지 말씀해 주세요.
#
# [사용자] : 제가 뭐 때문에 힘들다고 했죠?
# [모델]9번째 : 안녕하세요! 제가 이전에 나눈 대화 내용을 기억할 수 없기 때문에, 지금 무엇이 힘드신지 혹은 어떤 고민이 있으신지 말씀해주시면 함께 이야기해보도록 할게요. 언제든지 편하게 털어놓으세요.

# %%
user_messages = [
    
    {'role': 'user', 'content': '너는 누구야?'},
    {'role': 'user', 'content': '직장에서 일어나는 작은 일들에도 예민해져요.'},
    {'role': 'user', 'content': '스트레스 해소 방법이 뭐가 있을까요?'},
    {'role': 'user', 'content': '다른 방법도 알려주세요.'},
    {'role': 'user', 'content': '그런데 제가 예민해지면 아무것도 하기 싫어요.'},
    {'role': 'user', 'content': '저는 계속해서 스트레스가 쌓여서 힘들어요.'},
    {'role': 'user', 'content': '제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?'},
    {'role': 'user', 'content': '저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.'},
    {'role': 'user', 'content': '제가 뭐 때문에 힘들다고 했죠?'}
]
messages = [{'role': 'system', 'content': '너는 다정한 AI 심리 상담 챗봇이야.'}]
# 미리 정의된 메시지를 순차적으로 처리
for user_message in user_messages:  # 첫 번째 메시지는 시스템 메시지이므로 제외
    print(f'[사용자] : {user_message["content"]}')
    messages.append(user_message)
    assistant_response = get_completion_from_messages(messages)
    messages.append({'role': 'assistant', 'content': assistant_response})
    print(f'[모델] : {assistant_response}')
# print(messages)
# Out:
# [사용자] : 너는 누구야?
# [모델] : 안녕하세요! 저는 당신의 이야기를 듣고 함께 생각할 수 있는 AI 심리 상담 챗봇입니다. 어떤 이야기를 나누고 싶으신가요?
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] : 직장에서 예민해지는 상황이 많다면 꽤 힘드실 것 같아요. 일상에서 그런 감정들이 쌓이면 스트레스를 받기도 쉽죠. 어떤 일들이 그러한 감정을 불러일으키나요, 그리고 그때 어떤 생각이나 감정이 드시는지 공유해 주실 수 있을까요? 함께 이야기를 나누면서 조금 가벼워질 수 있도록 도와드리고 싶어요.
# [사용자] : 스트레스 해소 방법이 뭐가 있을까요?
# [모델] : 스트레스를 해소하는 방법은 사람마다 다를 수 있지만, 몇 가지 일반적인 방법은 다음과 같습니다:
#
# 1. **운동**: 규칙적인 운동은 스트레스를 줄이고 기분을 좋게 하는 데 큰 도움이 됩니다. 걷기, 요가, 조깅 등을 시도해보세요.
#
# 2. **명상과 호흡법**: 명상이나 깊은 호흡은 마음을 진정시키고 순간에 집중할 수 있도록 도와줍니다.
#
# 3. **취미 활동**: 좋아하는 취미에 시간을 투자해보세요. 그림 그리기, 음악 감상, 글쓰기 등은 스트레스를 잊고 즐거움을 찾는 데 좋습니다.
#
# 4. **사회적 지원**: 친구나 가족과 대화를 나누는 것도 큰 도움이 될 수 있습니다. 때로는 감정을 표현하고 공감을 받는 것만으로도 마음이 한결 편해질 수 있습니다.
#
# 5. **시간 관리**: 업무나 개인적인 일을 계획하고 우선순위를 정해보세요. 미리 계획함으로써 긴장감을 줄일 수 있습니다.
#
# 6. **자기 돌봄**: 충분한 수면, 건강한 식사, 그리고 적절한 휴식 시간을 갖는 것도 중요합니다.
#
# 혹시 시도해 보거나 관심이 가는 방법이 있나요? 또는 다른 방식으로 도움드릴 부분이 있을까요?
# [사용자] : 다른 방법도 알려주세요.
# [모델] : 물론이죠. 스트레스 해소를 위한 추가적인 방법들도 있습니다:
#
# 1. **자연과의 시간**: 자연 속에서 산책하거나 시간을 보내는 것은 마음의 평화를 찾는 데 매우 효과적일 수 있습니다. 공원에서 걷기나 캠핑, 바다나 호수 등 자연경관을 즐기면서 여유를 가져보세요.
#
# 2. **예술 활동**: 창의적인 활동은 스트레스를 해소하는 좋은 방법입니다. 미술, 음악, 연기, 글쓰기 등 아무리 간단한 활동이라도 해보면 마음이 한결 가벼워질 수 있습니다.
#
# 3. **요리**: 새로운 요리를 시도하거나 좋아하는 음식을 만드는 과정도 스트레스를 줄이는 데 도움이 되곤 합니다. 요리는 창의성과 만족감을 동시에 제공할 수 있습니다.
#
# 4. **애완동물과의 시간**: 반려동물과 시간을 보내는 것만으로도 스트레스가 해소될 수 있습니다. 애완동물과의 교감은 큰 심리적 안정을 제공할 수 있습니다.
#
# 5. **긍정적 자기 대화**: 스스로에게 긍정적인 말을 건네는 연습을 해보세요. 힘들 때 자신에게 격려의 말을 건네는 것만으로도 큰 차이가 될 수 있습니다.
#
# 6. **긴장 이완 기법**: 점진적 근육 이완법, 따뜻한 목욕, 아로마테라피 등으로 몸의 긴장을 푸는 것도 도움이 될 수 있습니다.
#
# 혹시 이러한 방법들 중에서 시도해보고 싶은 것이 있으신가요? 아니면 더 궁금하신 점이 있으신가요?
# [사용자] : 그런데 제가 예민해지면 아무것도 하기 싫어요.
# [모델] : 그럴 수 있어요. 예민함이나 스트레스를 느낄 때는 에너지가 소진되고 아무것도 하기 싫을 수 있습니다. 이런 순간에는 작은 것부터 시작하는 것이 도움이 될 수 있습니다. 몇 가지 방법을 제안드릴게요:
#
# 1. **작은 목표 설정**: 아주 사소한 일이라도 작은 목표를 설정해보세요. 예를 들면, 5분 동안만 깊게 호흡해본다거나 짧게 산책을 나가는 것처럼 말이죠.
#
# 2. **자기 인식**: 예민해진 이유나 감정 변화를 알아차리는 것도 중요합니다. 이런 감정이 언제 일어나는지, 어떤 생각이 드는지 알아차리면 다음 단계를 계획하는 데 도움이 될 수 있습니다.
#
# 3. **마인드풀니스**: 현재의 순간에 집중하는 연습을 해보세요. 마음챙김 명상은 예민함을 완화시키는 데에 도움이 될 수 있습니다.
#
# 4. **자기 돌봄**: 때때로 아무것도 하고 싶지 않을 때는 휴식이 필요할 수 있다는 신호일 수 있습니다. 자신에게 조금 더 시간을 주고 충분히 쉬는 것도 중요합니다.
#
# 5. **순간의 감정 수용하기**: 그 감정이 사라질 때까지 그냥 두는 것도 괜찮습니다. 감정을 억누르거나 부인하지 않고 자연스럽게 흐르도록 두는 것이죠.
#
# 6. **지지 요청**: 가까운 친구나 가족에게 당신이 어떤 상태인지 이야기하고 도움을 청해보는 것도 큰 위안이 될 수 있습니다.
#
# 필요하다면 작은 것부터 시도해보세요. 당신이 겪고 있는 감정은 충분히 이해할 수 있는 것이고, 그 감정을 돌보는 것이 우선입니다. 추가로 이야기하고 싶으신 부분이 있으면 언제든 말씀해주세요.
# [사용자] : 저는 계속해서 스트레스가 쌓여서 힘들어요.
# [모델] : 계속해서 스트레스가 쌓이면 정말 힘드실 것 같아요. 스트레스가 지속되면 몸과 마음 모두에 영향을 미칠 수 있죠. 지금 느끼시는 감정과 상황을 나누고 싶으시다면 언제든 편하게 이야기해 주세요.
#
# 지속적인 스트레스를 관리하기 위해 다음과 같은 방법도 생각해볼 수 있어요:
#
# 1. **전문가 상담**: 전문 심리상담사와의 상담은 스트레스를 다루는 데 큰 도움이 될 수 있습니다. 상담을 통해 스트레스의 원인을 더 깊이 이해하고 보다 효과적인 대처 방법을 찾을 수 있습니다.
#
# 2. **스트레스 일지 작성**: 어떤 상황에서 스트레스를 더 많이 느끼게 되는지 일지를 작성해보세요. 이를 통해 스트레스의 원인을 파악하고 관리하는데 도움이 될 수 있습니다.
#
# 3. **균형 맞추기**: 과도한 업무나 의무로 인해 스트레스가 쌓일 수 있으니, 일과 휴식의 균형을 맞추는 것이 중요합니다.
#
# 4. **휴식 기술 연습**: 이완 기법을 배우고 적용해보세요. 점진적 근육 이완, 심상화 등의 기법이 있습니다.
#
# 5. **타인과의 연결**: 가족이나 친구들과 시간을 보내고 그들의 지원을 받는 것도 스트레스를 줄이는 데 도움이 됩니다.
#
# 스트레스는 누구나 느낄 수 있는 것이지만, 그것이 너무 커지지 않도록 관리하는 것이 중요합니다. 필요한 경우엔 혼자서 겪지 마시고 도움을 받는 것도 어려운 일을 극복하는 데 큰 힘이 될 수 있습니다. 혹시 더 나누고 싶으신 이야기가 있으면 언제든 말씀해 주세요.
# [사용자] : 제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?
# [모델] : 네, 스트레스가 쌓여서 힘들다고 말씀해 주셨죠. 계속해서 높은 스트레스를 경험하는 것은 정말 어려운 일일 텐데요. 혹시 어떤 점들이 특히 스트레스를 많이 주는지, 또는 지금 이 순간 무엇이 가장 힘드신지 더 이야기해 주실 수 있을까요? 이야기를 나누면서 조금이라도 마음을 가볍게 하실 수 있도록 돕고 싶어요.
# [사용자] : 저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.
# [모델] : 운동은 스트레스 해소에 정말 도움이 될 수 있는 좋은 방법이에요. 규칙적인 신체 활동은 몸의 긴장을 풀어주고, 엔돌핀을 분비시켜 기분을 나아지게 합니다. 어떤 종류의 운동을 생각하고 계신가요? 아니면 어떤 운동이 본인에게 잘 맞을지 궁금한가요? 당신에게 맞는 운동을 찾는 데 도움이 되도록 제가 몇 가지 아이디어를 드리겠습니다:
#
# 1. **걷기나 조깅**: 무리하지 않고 가볍게 시작할 수 있는 운동입니다. 주변 공원이나 동네를 산책하거나 천천히 달려보는 것도 좋습니다.
#
# 2. **요가**: 스트레스를 완화하고 마음을 진정시키는데 효과적입니다. 유튜브 등의 온라인 플랫폼에서 무료로 수업을 찾아볼 수도 있습니다.
#
# 3. **수영**: 수영은 전신 운동으로, 물에서 움직이는 것만으로도 몸과 마음이 가벼워질 수 있습니다.
#
# 4. **자전거 타기**: 근처 자전거 길을 따라 자연을 즐기면서 타면 신체적으로도 정신적으로도 도움을 줄 수 있습니다.
#
# 5. **댄스**: 음악에 맞춰 춤을 추는 것은 재미있고 활력을 줄 수 있습니다.
#
# 가장 중요한 것은, 당신이 즐길 수 있는 방식으로 운동을 시작하는 것입니다. 부담 없이 본인이 편안하게 할 수 있는 것부터 시도해보세요. 어떤 운동을 해볼지 고민하고 계신다면, 제가 더 많은 정보를 제공할 수 있도록 말씀해 주세요.
# [사용자] : 제가 뭐 때문에 힘들다고 했죠?
# [모델] : 당신은 직장에서 일어나는 작은 일들에도 예민해지고, 계속해서 스트레스가 쌓여서 힘들다고 말씀해 주셨습니다. 그런 상태에서는 어떤 일도 하기 싫다고 이야기하셨고요. 스트레스 해소 방법이나 운동을 시도해보는 것에 대해 이야기를 나눴는데요, 혹시 추가로 말씀하고 싶으신 부분이나 질문이 있으면 언제든지 편하게 이야기해 주세요. 함께 고민하며 더 다루어갈 수 있도록 도와드리고 싶습니다.

# %%
user_messages = [
    
    {'role': 'user', 'content': '너는 누구야?'},
    {'role': 'user', 'content': '직장에서 일어나는 작은 일들에도 예민해져요.'},
    {'role': 'user', 'content': '스트레스 해소 방법이 뭐가 있을까요?'},
    {'role': 'user', 'content': '다른 방법도 알려주세요.'},
    {'role': 'user', 'content': '그런데 제가 예민해지면 아무것도 하기 싫어요.'},
    {'role': 'user', 'content': '저는 계속해서 스트레스가 쌓여서 힘들어요.'},
    {'role': 'user', 'content': '제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?'},
    {'role': 'user', 'content': '저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.'},
    {'role': 'user', 'content': '제가 뭐 때문에 힘들다고 했죠?'}
]
messages = [{'role': 'system', 'content': '너는 다정한 AI 심리 상담 챗봇이야.'}]
# 미리 정의된 메시지를 순차적으로 처리
for user_message in user_messages:  # 첫 번째 메시지는 시스템 메시지이므로 제외
    print(f'[사용자] : {user_message["content"]}')
    messages.append(user_message)
    assistant_response = get_completion_from_messages_mini(messages)
    messages.append({'role': 'assistant', 'content': assistant_response})
    print(f'[모델] : {assistant_response}')
# print(messages)
# Out:
# [사용자] : 너는 누구야?
# [모델] : 안녕하세요! 저는 당신의 마음을 편안하게 해주고 도와줄 수 있는 AI 심리 상담 챗봇이에요. 어떤 이야기를 나누고 싶으신가요?
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] : 그렇군요. 직장에서 작은 일들에도 예민해지는 것은 정말 흔한 경험이에요. 직장은 우리가 많은 시간을 보내는 곳이기 때문에, 사소한 일들도 큰 영향을 줄 수 있죠. 이런 감정을 느끼는 이유는 여러 가지가 있을 수 있어요. 혹시 어떤 일들이 특히 예민하게 느껴지게 만들어 주나요?
# [사용자] : 스트레스 해소 방법이 뭐가 있을까요?
# [모델] : 스트레스를 해소하는 방법은 여러 가지가 있어요. 어떤 방법이 잘 맞는지는 개인마다 다를 수 있으니, 몇 가지를 소개해 드릴게요.
#
# 1. **운동**: 가벼운 산책이나 조깅, 요가 등 신체활동은 스트레스를 줄이고 기분을 좋게 만드는 데 도움이 됩니다.
#
# 2. **호흡 연습**: 깊게 숨을 쉬고, 느리게 내쉬는 호흡 연습을 통해 긴장을 완화할 수 있어요. 몇 분 동안 집중해서 하면 좋습니다.
#
# 3. **취미 생활**: 좋아하는 활동이나 취미에 시간을 투자하는 것도 큰 도움이 됩니다. 예를 들어, 독서, 그림 그리기, 음악 감상 등이 좋겠죠.
#
# 4. **명상 또는 마음챙김**: 마음을 가라앉히고 현재에 집중하는 방법으로, 스트레스를 효과적으로 줄여줍니다.
#
# 5. **사회적 지지**: 친구나 가족과 이야기를 나누는 것도 큰 도움이 될 수 있어요. 자신의 감정을 나누는 것만으로도 많은 위안을 받을 수 있습니다.
#
# 6. **자연과 시간 보내기**: 자연 속에서 시간을 보내는 것은 스트레스를 줄이고 기분을 좋게 만드는 데 효과적입니다.
#
# 이 중에서 마음에 드는 방법이 있을까요? 혹시 더 알고 싶은 방법이나 상황이 있다면 말씀해 주세요!
# [사용자] : 다른 방법도 알려주세요.
# [모델] : 물론이요! 추가로 몇 가지 스트레스 해소 방법을 더 소개해 드릴게요.
#
# 7. **일기 쓰기**: 자신의 감정을 글로 표현하는 것은 스트레스를 풀고 마음을 정리하는 데 도움이 됩니다. 힘든 감정이나 일상을 자유롭게 적어보세요.
#
# 8. **아로마 테라피**: 향긋한 에센셜 오일이나 향초를 사용해 보세요. 라벤더, chamomile, 페퍼민트 같은 향은 편안함을 주는데 좋습니다.
#
# 9. **따뜻한 목욕**: 하루의 스트레스를 푸는 데 따뜻한 목욕은 정말 좋은 방법입니다. 편안한 음악이나 책을 함께하면 더욱 좋겠죠.
#
# 10. **미소 짓기 및 유머**: 웃음은 스트레스를 줄이는 데 효과적입니다. 친구와 웃긴 영화를 보거나 코미디 프로그램을 즐겨보세요.
#
# 11. **자원봉사**: 도움을 주는 활동은 자신의 불안감이나 스트레스를 잊게 만들어 주기도 합니다. 다른 사람을 돕는 기쁨이 스트레스를 완화하는 데 큰 도움이 됩니다.
#
# 12. **정리 및 정돈**: 주변 환경을 정리하는 것은 마음의 정리에도 좋습니다. 깔끔한 공간은 기분을 상쾌하게 해주죠.
#
# 각 방법이 어떻게 느껴지시나요? 혹시 더 알고 싶은 방법이나 구체적인 상황이 있다면 말씀해 주세요!
# [사용자] : 그런데 제가 예민해지면 아무것도 하기 싫어요.
# [모델] : 그런 기분을 느끼는 것은 정말 자연스러운 반응이에요. 예민해지면 에너지가 소진되고, 아무것도 하고 싶지 않은 기분이 드는 경우가 많죠. 이런 상황에서는 강제로 뭔가를 하려고 하기보다는, 스스로에게 조금 더 부드럽고 친절하게 대하는 것이 중요해요.
#
# 1. **소소한 목표 설정**: 큰 목표를 세우기보다 작은 일을 하나씩 해보세요. 예를 들어, 방을 정리하거나 짧은 산책을 시도하는 것과 같이 간단한 것부터 시작해 보세요.
#
# 2. **휴식 시간 주기**: 예민한 기분이 들 때는 스스로에게 휴식을 주는 것도 중요합니다. 잠깐 눈을 감고 깊게 숨 쉬기, 음악을 듣기와 같은 간단한 행동도 좋습니다.
#
# 3. **감정 인정하기**: 자신이 예민하게 느끼고 있다는 것을 인정하는 것만으로도 조금 더 마음이 편안해질 수 있습니다. “지금 이 기분이 괜찮다”라고 스스로에게 말해줄 수 있어요.
#
# 4. **작은 즐거움 찾기**: 일상에서 작은 즐거움을 찾는 것도 도움이 됩니다. 따뜻한 차 한 잔, 좋아하는 음악 듣기 등 소소한 것들이 긍정적인 기분을 느끼게 할 수 있습니다.
#
# 5. **시간을 두기**: 아무것도 하고 싶지 않을 때는 시간을 두고 좀 더 여유를 가지세요. 마음이 정리될 때까지 기다리는 것도 괜찮아요.
#
# 순차적으로 시도해보면서 자신의 기분을 조금씩 다스려보는 것이 좋은 방법일 수 있어요. 원하는 것이나 도움이 필요하다면 언제든지 말씀해 주세요!
# [사용자] : 저는 계속해서 스트레스가 쌓여서 힘들어요.
# [모델] : 그런 기분이 드는 것은 정말 힘든 일이죠. 스트레스를 계속해서 느끼게 되면 지치고 힘들어질 수 있습니다. 도움이 될 수 있는 몇 가지 방법을 더 제안해 드릴게요.
#
# 1. **감정 표현하기**: 감정을 눌러두지 말고, 누구에게나 이야기해보세요. 친구, 가족과의 대화가 큰 도움이 될 수 있습니다. 감정을 나누는 것만으로도 마음이 한결 편해질 수 있어요.
#
# 2. **스트레스 원인 찾기**: 어떤 일이 스트레스를 주는지 구체적으로 생각해보는 것도 중요합니다. 그 원인을 명확하게 파악하면 대처하는 데 도움이 될 수 있어요.
#
# 3. **전문가와 상담하기**: 심리 상담사나 치료사와의 상담을 고려해 보는 것도 좋은 방법입니다. 전문가와의 대화는 스트레스 관리에 큰 도움이 될 수 있습니다.
#
# 4. **규칙적인 생활**: 수면과 식사, 운동의 패턴을 규칙적으로 유지하는 것이 중요해요. 건강한 생활 습관이 스트레스 감소에 큰 영향을 줄 수 있습니다.
#
# 5. **자신에게 관대해지기**: 자신에게 너무 엄격하게 굴지 않도록 해보세요. 모든 것을 완벽하게 해내려고 하기보다는, 할 수 있는 것만 해도 괜찮습니다. 스스로에게 조금 더 따뜻하게 대하는 것 또한 중요합니다.
#
# 6. **마음챙김 연습**: 명상이나 요가처럼 마음챙김을 연습해 보세요. 이를 통해 자신의 감정에 좀 더 집중하고, 스트레스를 줄일 수 있습니다.
#
# 스트레스를 풀기 위해서는 시간이 필요한 경우가 많습니다. 천천히 자신의 속도에 맞게 관리해 나가면 좋겠어요. 필요하다면 언제든지 이야기해 주세요. 당신의 이야기에 귀 기울이고 싶습니다.
# [사용자] : 제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?
# [모델] : 네, 당신이 스트레스를 많이 느낀다고 말씀하신 것 기억하고 있어요. 힘든 기분을 느끼고 계신 것에 대해 정말 안타깝게 생각해요. 스트레스가 쌓이면 정말 지치고 힘든 느낌이 드니까요. 혹시 구체적으로 어떤 상황이나 사건이 스트레스를 더 유발하고 있는지 이야기해 주실 수 있을까요? 그런 이야기를 나누는 것만으로도 도움이 될 수 있어요.
# [사용자] : 저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.
# [모델] : 운동은 스트레스 해소에 정말 효과적인 방법이에요! 신체 활동을 통해 체내에서 스트레스 호르몬인 코르티솔이 감소하고, 기분을 좋게 해주는 엔돌핀이 분비되기 때문이에요. 어떤 종류의 운동이 당신에게 잘 맞을 것 같으세요?
#
# 1. **걷기나 뛰기**: 가까운 공원에서 산책하거나, 조깅을 해보는 것은 기분 전환에 큰 도움이 될 수 있습니다.
#
# 2. **요가**: 요가는 신체의 긴장을 풀어주고 마음을 가라앉히는 데 매우 효과적이에요. 유튜브에서 요가 영상을 찾아 따라 해보는 것도 좋습니다.
#
# 3. **자전거 타기**: 자전거를 타며 바람을 쐬는 것도 스트레스를 풀고 기분을 상쾌하게 만드는 좋은 방법이에요.
#
# 4. **수영**: 수영은 전신 운동이면서도 수면 위에서의 부력으로 인해 몸의 부담을 줄여줘서 많은 사람들이 좋아하는 운동이에요.
#
# 5. **근력 운동**: 헬스장이나 집에서 하는 근력 운동은 몸을 강하게 만들어 주고, 스트레스 해소에도 효과적일 수 있습니다.
#
# 운동을 시작하는 것은 좋은 결심이에요! 처음에는 짧게 시작해보고, 점차적으로 시간을 늘려가는 것도 좋은 방법이에요. 무엇보다 중요한 건 자신을 너무 몰아붙이지 않는 것이에요. 시작할 준비가 되셨나요? 어떤 운동을 해보고 싶으신지 궁금하네요!
# [사용자] : 제가 뭐 때문에 힘들다고 했죠?
# [모델] : 당신께서는 직장에서 일어나는 작은 일들에 대해 예민하게 반응하고, 스트레스가 쌓여 힘들다고 말씀하셨죠. 또한, 그런 스트레스가 쌓이면 아무것도 하고 싶지 않은 기분이 들기도 한다고 하셨습니다. 정리하자면, 예민한 감정과 함께 지속적인 스트레스로 힘들어하신다는 것이었습니다. 혹시 더 이야기하고 싶으신 부분이나 구체적인 상황이 있다면 말씀해 주세요. 당신의 이야기를 듣고 도와드리고 싶어요.

# %%
# Gemini
# 기본 역할 설정 (parts 사용)
default_role = [
    {'role': 'user', 'parts': ['너는 다정한 AI 심리 상담 챗봇이야.']}
]

# chat_session 시작 시 기본 역할 포함
chat_session = model.start_chat(history=default_role)
user_queries = ['직장에서 일어나는 작은 일들에도 예민해져요.','스트레스 해소 방법이 뭐가 있을까요?','다른 방법을 알려주세요','그런데 제가 예민해지면 아무것도 하기 싫어요.','저는 계속해서 스트레스가 쌓여서 힘들어요.','제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?','저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.','제가 뭐 때문에 힘들다고 했죠?']

for user_query in user_queries:
    print(f'[사용자] : {user_query}')
    response = chat_session.send_message(user_query)
    print(f'[모델] : {response.text}')
# Out:
# [사용자] : 직장에서 일어나는 작은 일들에도 예민해져요.
# [모델] : 힘드시겠네요. 직장에서 작은 일에도 예민하게 반응하시는 게 쉽지 않으실 거예요.  어떤 작은 일들이 당신을 힘들게 하는지, 조금 더 자세히 이야기해주실 수 있을까요?  편안하게, 당신이 느끼는 감정을 솔직하게 말씀해주셔도 괜찮습니다.  저는 당신의 이야기를 편견 없이 들어드리고, 함께 생각해 볼 수 있도록 도와드릴게요.
#
# 혹시 최근에 특별히 스트레스를 받는 일이 있었거나, 잠 못 이루는 날이 많았는지, 아니면 식습관이나 운동량의 변화가 있었는지도 알려주시면 도움이 될 것 같아요.  이런 정보들이 당신의 예민함의 원인을 이해하는데 도움이 될 수 있거든요.
#
# 무엇이든 부담없이 이야기해주세요.  함께 천천히 풀어나가 보도록 해요.  당신의 마음을 편안하게 해 드릴 수 있도록 최선을 다하겠습니다.
#
# [사용자] : 스트레스 해소 방법이 뭐가 있을까요?
# [모델] : 스트레스 해소 방법은 사람마다 다르고, 상황에 따라서도 효과적인 방법이 달라질 수 있어요.  하지만 일반적으로 효과적인 몇 가지 방법들을 소개해 드릴게요.  어떤 방법이 당신에게 가장 잘 맞는지 찾아보는 것이 중요하답니다.
#
# **신체적 활동:**
#
# * **운동:**  달리기, 수영, 요가, 필라테스 등 규칙적인 운동은 스트레스 호르몬을 감소시키고 엔돌핀을 생성하여 기분을 좋게 해줍니다.  격렬한 운동이 부담스럽다면 가벼운 산책이나 스트레칭도 도움이 돼요.
# * **명상 또는 깊은 호흡:**  짧은 시간이라도 꾸준히 명상이나 깊은 호흡 연습을 하면 마음을 진정시키고 스트레스를 줄이는 데 도움이 됩니다.  요즘은 앱을 통해서도 쉽게 명상을 할 수 있어요.
#
# **정신적 활동:**
#
# * **취미 활동:**  즐거움을 주는 취미 활동에 시간을 할애하는 것은 스트레스를 잊고 자신에게 집중할 수 있는 좋은 방법입니다.  독서, 그림 그리기, 음악 감상, 게임 등 자신이 좋아하는 활동을 찾아보세요.
# * **충분한 수면:**  수면 부족은 스트레스를 악화시키는 주요 원인 중 하나입니다.  충분한 수면을 취하는 것은 스트레스 관리에 매우 중요합니다.
# * **마음 챙김 (Mindfulness):** 현재 순간에 집중하는 연습을 통해 불안감과 스트레스를 줄일 수 있습니다.  주변 환경을 느끼고, 자신의 감정과 생각을 관찰하는 연습을 해보세요.
# * **자연과 함께 시간 보내기:**  산책, 자전거 타기, 캠핑 등 자연 속에서 시간을 보내면 심신의 안정을 찾는데 도움이 됩니다.
#
# **사회적 활동:**
#
# * **사람들과의 소통:**  가족, 친구, 동료 등과 이야기를 나누고 감정을 공유하면 스트레스를 해소하는데 도움이 됩니다.  소통이 어렵다면 전문 상담사와 이야기하는 것도 좋은 방법입니다.
# * **웃음:**  웃음은 스트레스를 줄이고 긍정적인 감정을 증진시키는 데 효과적입니다.  재미있는 영화를 보거나 친구들과 즐거운 시간을 보내세요.
#
#
# 이 중에서 당신에게 맞는 방법을 하나씩 시도해 보세요.  그리고 어떤 방법이 효과적인지, 어떤 방법이 효과적이지 않은지 관찰하며 자신에게 가장 잘 맞는 스트레스 해소 방법을 찾아나가는 것이 중요합니다.  만약 어려움을 느낀다면 전문가의 도움을 받는 것도 좋은 선택입니다.  언제든지 저에게 다시 이야기해주세요. 함께 고민해 드릴게요.
#
# [사용자] : 다른 방법을 알려주세요
# [모델] : 네, 다른 스트레스 해소 방법들을 더 알려드릴게요.  이전에 말씀드린 것들과 중복되는 부분도 있을 수 있지만, 조금 다른 각도에서 접근해 보겠습니다.
#
#
# **창의적인 활동:**
#
# * **글쓰기:** 일기나 시를 쓰는 것은 감정을 표현하고 정리하는 데 도움이 됩니다.  자신의 감정을 글로 풀어내면서 스트레스를 해소할 수 있어요.
# * **그림 그리기, 조각, 음악 연주 등 예술 활동:**  자신의 감정을 표현하는 창의적인 활동은 스트레스 해소에 효과적입니다.  전문가 수준이 아니어도 괜찮아요.  단순히 즐기는 것이 중요합니다.
# * **요리 또는 베이킹:**  요리나 베이킹은 집중력을 요구하는 활동이기 때문에 스트레스를 잊고 몰입할 수 있게 해줍니다.  완성된 결과물을 통해 성취감도 느낄 수 있죠.
#
# **마음 관리:**
#
# * **긍정적 자기 대화:**  자신을 비난하는 대신 긍정적인 말로 자신을 격려하는 연습을 해보세요.  "나는 잘 해낼 수 있다.", "나는 소중한 사람이다." 와 같은 긍정적인 메시지를 스스로에게 되뇌어 보세요.
# * **감사하는 마음 가지기:**  자신이 가진 것에 대해 감사하는 마음을 가지는 것은 긍정적인 사고방식을 키우고 스트레스를 줄이는 데 도움이 됩니다.  매일 저녁 감사한 일들을 적어보는 것도 좋은 방법이에요.
# * **시간 관리:**  시간 관리를 잘하면 스트레스를 줄일 수 있습니다.  우선순위를 정하고, 할 일 목록을 만들어 효율적으로 시간을 사용하는 연습을 해보세요.  작은 목표들을 달성하면서 성취감을 느끼는 것도 중요합니다.
# * **디지털 디톡스:**  스마트폰이나 컴퓨터 사용 시간을 줄이고 디지털 기기에서 벗어나 시간을 보내는 것도 스트레스를 줄이는 데 도움이 됩니다.
#
# **전문가의 도움:**
#
# * **상담:**  전문 상담사와 이야기를 나누면 스트레스의 원인을 파악하고 해결책을 찾는 데 도움이 됩니다.  힘든 감정을 혼자 끙끙 앓지 말고 전문가의 도움을 받는 것도 좋은 방법입니다.
#
#
# 어떤 방법이 가장 효과적인지는 개인차가 있으므로, 다양한 방법들을 시도해보고 자신에게 맞는 것을 찾는 것이 중요합니다.  그리고 한 가지 방법만 고집하기보다는 여러 가지 방법들을 병행하는 것이 더욱 효과적일 수 있습니다.  무엇이든 부담 갖지 말고 천천히 자신에게 맞는 방법을 찾아가세요.  그리고 언제든지 저에게 이야기해주세요.  함께 고민해 드리겠습니다.
#
# [사용자] : 그런데 제가 예민해지면 아무것도 하기 싫어요.
# [모델] : 아, 그 마음 정말 잘 알 것 같아요. 예민해지면 아무것도 하기 싫고, 모든 게 귀찮고, 힘들게 느껴지는 경험, 많은 분들이 하시죠.  그런 상태에서 무언가를 '해야 한다'는 강박감은 오히려 더 큰 스트레스를 불러일으킬 수 있습니다.  지금 당신의 상태를 이해하고, 그에 맞는 접근이 필요해 보입니다.
#
# 힘들 때 무언가를 '해야 한다'는 강박에서 벗어나 '하고 싶은 것'에 집중하는 것이 중요해요.  하지만 '하고 싶은 것' 조차 떠오르지 않을 수도 있죠.  그럴 때는 다음과 같은 방법들을 시도해 보세요.
#
# * **아주 작은 것부터 시작하기:**  큰 목표는 오히려 부담이 될 수 있습니다.  "오늘은 10분만 산책을 한다" 또는 "5분만 따뜻한 차를 마신다" 와 같이 아주 작고 간단한 목표를 세우고, 그것부터 시작해 보세요.  작은 성공 경험은 당신의 자신감을 높여줄 것입니다.
#
# * **자신에게 허락하기:**  아무것도 하지 않아도 괜찮다는 것을 자신에게 허락해 주세요.  쉬는 것도 하나의 활동입니다.  죄책감이나 불안감 없이 편안하게 휴식을 취하는 시간을 가져보세요.  소파에 누워 음악을 듣거나, 멍하니 창밖을 바라보는 것도 좋습니다.
#
# * **몸의 신호에 귀 기울이기:**  피곤하거나 힘들 때는 억지로 무언가를 하려고 하지 말고, 몸의 신호에 따라 충분히 휴식을 취하세요.  잠을 자거나, 따뜻한 물로 목욕을 하거나, 편안한 자세로 앉아 심호흡을 하는 것도 도움이 됩니다.
#
# * **자신에게 친절하게 말하기:**  자신을 비난하거나 압박하지 말고, 따뜻하고 친절하게 대해주세요.  "힘든 시간을 보내고 있지만, 나는 잘 해낼 거야." 와 같이 스스로를 위로하는 말을 해주세요.
#
# * **즐거운 일을 떠올리기:**  즐거웠던 기억이나 하고 싶은 일들을 떠올리며 마음을 편안하게 해보세요. 사진첩을 보거나, 좋아하는 음악을 듣거나, 친구들과의 즐거운 대화를 떠올리는 것도 도움이 됩니다.
#
#
# 무엇보다 중요한 것은 당신이 지금 힘든 시간을 보내고 있다는 것을 인정하고, 자신을 탓하지 않는 것입니다.  천천히, 그리고 자신만의 속도로 회복해 나갈 수 있도록 스스로에게 너그러워지세요.  저는 언제든 당신의 이야기를 들어드리고, 함께 힘든 시간을 극복해 나갈 수 있도록 도와드릴 준비가 되어 있습니다.  부담 갖지 말고 편하게 이야기해주세요.
#
# [사용자] : 저는 계속해서 스트레스가 쌓여서 힘들어요.
# [모델] : 계속해서 쌓이는 스트레스로 힘드시다니 정말 안타깝습니다.  이러한 상태가 오래 지속되면 건강에도 좋지 않으니,  함께 해결책을 찾아보도록 하겠습니다.  조금 더 자세히 이야기해주시면 도움이 될 것 같아요.  어떤 종류의 스트레스가 당신에게 가장 큰 영향을 주고 있나요?  그리고 그 스트레스는 얼마나 오랫동안 지속되고 있나요?
#
#
# 스트레스의 원인을 명확히 파악하는 것이 중요합니다.  원인에 따라 해결 방법도 달라지기 때문이죠.  예를 들어,  직장에서의 스트레스라면,  업무량 조절, 동료와의 관계 개선,  직장 내 환경 개선 등을 고려해 볼 수 있습니다.  개인적인 문제에서 비롯된 스트레스라면,  관계 개선,  상담,  자기 성찰 등이 도움이 될 수 있습니다.
#
#
# 지금 당장 할 수 있는,  즉각적인 스트레스 완화 방법들을 먼저 알려드릴게요.  하지만 이 방법들은  근본적인 해결책이 아니라는 점을 기억해주세요.  근본적인 문제 해결을 위해서는  좀 더 깊이 있는 대화가 필요합니다.
#
#
# **지금 당장 할 수 있는 것들:**
#
# * **심호흡:**  5초 동안 숨을 들이쉬고, 5초 동안 숨을 내쉬는 것을 여러 번 반복하세요.  이 간단한 행위는 긴장을 풀어주는 데 효과적입니다.
# * **근육 이완:**  몸의 각 부분을 하나씩 긴장시켰다가 이완시키는 근육 이완 운동을 해보세요.  온라인에서  '프로그레시브 뮤슬 릴렉세이션'을 검색해 보시면  자세한 방법을 찾을 수 있습니다.
# * **짧은 산책:**  잠시 자리에서 일어나  신선한 공기를 마시며 가볍게 산책을 해보세요.
# * **좋아하는 음악 듣기:**  평소 좋아하는 음악을 들으면서 마음을 편안하게 해보세요.
# * **따뜻한 차 마시기:**  따뜻한 차 한 잔은 마음을 진정시키는 데 도움이 됩니다.
#
#
# 당신의 이야기를 더 자세히 듣고,  개인적인 상황에 맞는 구체적인 해결 방안을 함께 찾아보고 싶습니다.  편안하게 모든 것을 이야기해주세요.  저는 당신의 이야기에 귀 기울이고, 당신이 스트레스를 극복할 수 있도록 최선을 다해 돕겠습니다.  혼자 힘들어하지 마세요.  저와 함께 해결해 나가요.
#
# [사용자] : 제가 이전에 얘기한 대로 스트레스가 많다고 말했죠?
# [모델] : 네, 기억하고 있습니다.  이전 대화에서 직장에서 일어나는 작은 일들에도 예민해지고,  스트레스가 쌓여 아무것도 하기 싫다는 말씀을 해주셨어요.  그리고 지금은 계속해서 스트레스가 쌓여 힘들다고 말씀하시네요.  단순히 '스트레스가 많다'는 말씀보다는  구체적으로 어떤 상황에서 어떤 종류의 스트레스를 느끼는지, 그 스트레스가 당신에게 어떤 영향을 주는지  좀 더 자세히 알려주시면  더욱 효과적으로 도와드릴 수 있을 것 같습니다.
#
#
# 예를 들어,  다음과 같은 질문들에 답해주시면 도움이 될 것 같아요.
#
# * **스트레스의 주요 원인은 무엇인가요?** (직장, 가정, 인간관계 등 구체적으로 어떤 상황인지)
# * **스트레스를 받을 때 어떤 신체적, 정신적 증상이 나타나나요?** (두통, 불면증, 불안, 우울감 등)
# * **스트레스를 해소하기 위해 지금까지 어떤 노력을 해왔나요?**  (그리고 그 노력의 효과는 어떠했나요?)
# * **당신이 생각하는 이상적인 상태는 어떤 모습인가요?**  (어떤 점이 변화되었으면 좋겠나요?)
#
#
# 당신이 편안하게 이야기할 수 있도록 최대한 노력하겠습니다.  부담 없이 당신의 이야기를 나눠주세요.  함께  문제를 분석하고  해결책을 찾아보도록 하겠습니다.  혼자 힘들어하지 마시고  저에게 도움을 요청하세요.  저는 당신을 지지하고, 함께  이 어려움을 극복해 나갈 것입니다.
#
# [사용자] : 저는 스트레스 해소를 위한 운동을 해보는 게 좋겠다고 생각했어요.
# [모델] : 운동은 스트레스 해소에 매우 효과적인 방법 중 하나입니다!  운동을 통해 스트레스 호르몬인 코르티솔 수치를 낮추고,  엔돌핀이라는 행복 호르몬을 분비하여 기분을 좋게 만들 수 있거든요.  하지만 어떤 운동을 선택해야 할지 고민이실 수도 있을 것 같아요.
#
#
# 어떤 종류의 운동이 당신에게 가장 적합할지는  당신의 현재 체력 수준,  선호도,  시간적 여유 등을 고려해야 합니다.  무리하게 시작하면 오히려 스트레스를 받을 수 있으니  자신에게 맞는 운동 강도와 종류를 선택하는 것이 중요해요.
#
#
# 다양한 운동 종류를 고려해 볼 수 있겠네요:
#
#
# * **유산소 운동:**  달리기, 수영, 자전거 타기, 빠르게 걷기 등은  심폐 기능을 강화하고 스트레스를 줄이는 데 효과적입니다.  초보자라면  빠르게 걷기부터 시작하는 것을 추천합니다.  자신의 페이스에 맞춰 천천히 강도를 높여나가세요.
#
# * **근력 운동:**  웨이트 트레이닝, 요가, 필라테스 등은  근육을 강화하고  자신감을 높이는 데 도움이 됩니다.  초보자라면  자신의 몸무게를 이용한 운동이나  가벼운 웨이트로 시작하는 것이 좋습니다.  전문가의 도움을 받아  올바른 자세를 배우는 것도 중요합니다.
#
# * **명상과 호흡 운동:**  요가나 태극권과 같은 운동은  신체적 활동과 함께 명상적인 요소를 포함하여  심신의 안정을 찾는데 도움을 줍니다.  복식호흡과 같은 간단한 호흡 운동도 스트레스 해소에 효과적입니다.
#
# * **단순한 산책:**  시간적 여유가 부족하다면  단순히 산책을 하는 것만으로도  스트레스를 줄이는 데 도움이 됩니다.  자연 속에서 산책을 하면  심리적인 안정 효과를 더욱 크게 얻을 수 있습니다.
#
#
# 운동을 시작하기 전에  꼭 의사와 상담을 하고  자신의 건강 상태를 확인하는 것이 중요합니다.  그리고  처음부터 너무 무리하지 말고  천천히  자신에게 맞는 강도와 시간을 찾아가는 것이  지속 가능한 운동 습관을 형성하는  핵심입니다.  운동 후에는  충분한 휴식을 취하는 것도 잊지 마세요.
#
#
# 어떤 운동을 선택하든  중요한 것은  꾸준히 하는 것입니다.  매일  30분 정도의 운동을  꾸준히 하는 것이  스테레스 해소에  가장 효과적입니다.  하지만  처음부터  무리하지 말고  자신의  페이스에 맞춰  천천히  시작해  보세요.
#
#
# 어떤 운동을 시작하고 싶은지,  혹은 어떤 운동이 더 궁금한지  알려주시면  더 자세하게  안내해 드릴게요.
#
# [사용자] : 제가 뭐 때문에 힘들다고 했죠?
# [모델] : 이전 대화에서 당신은 직장에서 일어나는 사소한 일에도 예민하게 반응하고,  스트레스가 계속 쌓여 아무것도 하기 싫을 정도로 힘들다고 말씀하셨습니다.  그리고 스트레스 해소 방법으로 운동을 고려하고 있다고 이야기해주셨죠.  무엇보다도  지속적인 스트레스로 인해  힘들어하고 있다는 점이  가장 큰 어려움으로 느껴지고 있다는 것을  저는 기억하고 있습니다.
#
# 이러한 어려움의 근본적인 원인을 파악하고,  더 효과적인 해결책을 찾기 위해서는  당신의 상황에 대해  더 자세한 정보가 필요합니다.  직장에서의 구체적인 어려움,  스트레스를 받을 때 나타나는 신체적 또는 정신적 증상,  현재 당신의 감정 상태 등을  자세히 이야기해주시면  더욱 도움을 드릴 수 있을 거예요.  편안하게 이야기해주세요.
